# %%
# !pip install --upgrade-strategy only-if-needed altair==3.2.0 vega_datasets==0.7.0 --user
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/34/24/3e50e226a79db1bb1427bf8c58cc4dc7c2f74c39b728af005f4b11d1760c/altair-3.2.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/0a/53/00c0d891e2da61442745aa5f6677e93b68ea247b49ed70a7da1dd764760f/vega_datasets-0.7.0-py2.py3-none-any.whl
# ...
# Processing /home/jupyter/.cache/pip/wheels/e1/8b/65/3294e5b727440250bda09e8c0153b7ba19d328f661605cb151/toolz-0.10.0-cp35-none-any.whl
# ...

# %%
import altair as alt
from vega_datasets import data

source = data.cars()

alt.Chart(source).mark_circle(size=60).encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
    tooltip=['Name', 'Origin', 'Horsepower', 'Miles_per_Gallon']
).interactive()
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
source
# Out:
#      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0            12.0          8         307.0       130.0              18.0
# 1            11.5          8         350.0       165.0              15.0
# 2            11.0          8         318.0       150.0              18.0
# 3            12.0          8         304.0       150.0              16.0
# 4            10.5          8         302.0       140.0              17.0
# ..            ...        ...           ...         ...               ...
# 401          15.6          4         140.0        86.0              27.0
# 402          24.6          4          97.0        52.0              44.0
# 403          11.6          4         135.0        84.0              32.0
# 404          18.6          4         120.0        79.0              28.0
# 405          19.4          4         119.0        82.0              31.0
#
#                           Name  Origin  Weight_in_lbs       Year
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer

imputer = SimpleImputer()

mpg = np.asarray(source['Miles_per_Gallon']).reshape(-1, 1)
mpg_imputed = imputer.fit_transform(mpg)
horsepower = np.asarray(source['Horsepower']).reshape(-1, 1)
horsepower_imputed = imputer.fit_transform(horsepower)

reg = LinearRegression().fit(horsepower_imputed, mpg_imputed)

fig = plt.figure()
ax = plt.axes()

ax.plot(horsepower_imputed, reg.predict(horsepower_imputed));
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-3ec62459a017> in <module>
#       3
#       4 from sklearn.linear_model import LinearRegression
# ----> 5 from sklearn.impute import SimpleImputer
#       6
#       7 imputer = SimpleImputer()
#
# ImportError: No module named 'sklearn.impute'
